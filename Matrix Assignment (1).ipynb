# %% [markdown]
# # Matrix Assignment

# %%
class easter:
    def __init__(self,id):
        self.id = s2(id)
        id='100'
temp= easter(10)
print temp.id
# Out:
#   File "<ipython-input-4-df1de37250c8>", line 6
#     print temp.id
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(temp.id)?

# %% [markdown]
# # 1. Transpose of Matrix

# %%
def transpose(row, col):
    print("Enter the elements of matrix: ")
    matrix = [[int(input()) for j in range(col)] for i in range(row)]
    print("<-------- Your Matrix -------->")
    for ele in matrix:
        print(ele)
    result = [[0 for i in range(row)] for j in range(col)]
    for r in range(row):
        for c in range(col):
            result[c][r] = matrix[r][c]
            
    print("<----- Transpose of Matrix ----->")
    for r in range(row): 
        for c in range(col): 
            print(result[i][j], end = " ") 
        print() 

        
        
def main1():
    row = int(input("Enter the number of rows : "))
    col = int(input("Enter the number of columns : "))
    
    transpose(row,col)
    
    
    
if __name__ == "__main__":
    main()
# Out:
# Enter the number of rows : 2
# Enter the number of columns : 2
# Enter the elements of matrix:
# 2
# 3
# 4
# 5
# <-------- Your Matrix -------->
# [2, 3]
# [4, 5]
# <----- Transpose of Matrix ----->
# 2 4
# 3 5

# %% [markdown]
# # 2. Addition, Subtraction, Multiplication

# %%
 def addition():
    row = int(input("Enter the no. of rows: "))
    col = int(input("Enter the no. of columns: "))
    print("Enter the elements of matrix 1: ")
    matrix1 = [[int(input()) for j in range(col)] for i in range(row)]
    print("Enter the elements of matrix 2: ")
    matrix2 = [[int(input()) for j in range(col)] for i in range(row)]
    print("<-------- Matrix 1 -------->")
    for ele in matrix1:
        print(ele)
    print("<-------- Matrix 2 -------->")
    for ele in matrix2:
        print(ele)
        
    result = [[0 for i in range(row)] for j in range(col)]
    for i in range(row):
        for j in range(col):
            result[i][j] = matrix1[i][j] + matrix2[i][j]
            
    print("<----- Addition of matrix 1 and matrix 2  ----->")
    for i in range(row): 
        for j in range(col): 
            print("\t",result[i][j], end = " ") 
        print() 
        
    

def subtraction():
    row = int(input("Enter the no. of rows: "))
    col = int(input("Enter the no. of columns: "))
    print("Enter the elements of matrix 1: ")
    matrix1 = [[int(input()) for j in range(col)] for i in range(row)]
    print("Enter the elements of matrix 2: ")
    matrix2 = [[int(input()) for j in range(col)] for i in range(row)]
    print("<-------- Matrix 1 -------->")
    for ele in matrix1:
        print(ele)
    print("<-------- Matrix 2 -------->")
    for ele in matrix2:
        print(ele)
        
    result = [[0 for i in range(row)] for j in range(col)]
    for r in range(row):
        for c in range(col):
            result[r][c] = matrix1[r][c]- matrix2[r][c]
            
    print("<----- Subtraction of matrix 1 and matrix 2  ----->")
    for r in range(row): 
        for c in range(col): 
            print("\t",result[r][c], end = " ") 
        print() 
        
def transpose():
    row = int(input("Enter the number of rows : "))
    col = int(input("Enter the number of columns : "))
    print("Enter the elements of matrix: ")
    matrix = [[int(input()) for j in range(col)] for i in range(row)]
    print("<-------- Your Matrix -------->")
    for ele in matrix:
        print(ele)
    result = [[0 for i in range(row)] for j in range(col)]
    for r in range(row):
        for c in range(col):
            result[c][r] = matrix[r][c]
            
    print("<----- Transpose of Matrix ----->")
    for i in range(row): 
        for j in range(col): 
            print(result[i][j], end = " ") 
        print() 

        
        
def multiplication():
    
    n1 = int(input("Enter the no. of rows of matrix 1 : "))
    n2 = int(input("Enter the no. of columns of matrix 1: "))
    n3 = int(input("Enter the no. of columns of matrix 2: "))
    print("Enter the elements of matrix 1: ")
    matrix1 = [[int(input()) for j in range(n2)] for i in range(n1)]
    print("Enter the elements of matrix 2: ")
    matrix2 = [[int(input()) for j in range(n3)] for i in range(n2)]
    print("<-------- Matrix 1 -------->")
    for ele in matrix1:
        print(ele)
    print("<-------- Matrix 2 -------->")
    for ele in matrix2:
        print(ele)
            
    print("<----- Multiplication of matrix 1 and matrix 2 ----->")
    for i in range(n1): 
        for j in range(n3):
            for k in range(n2):
                result+= matrix1[i][k]*matrix2[k][j]
                print("\t",result[i][j], end = " ") 
        print() 
        
        
def symentric():
    row = int(input("Enter the number of rows : "))
    col = int(input("Enter the number of columns : "))
    print("Enter the elements of matrix: ")
    matrix = [[int(input()) for j in range(col)] for i in range(row)]
    print("<-------- Your Matrix -------->")
    for ele in matrix:
        print(ele)
    result = [[0 for i in range(row)] for j in range(col)]
    for r in range(row):
        for c in range(col):
            result[c][r] = matrix[r][c]
            
    print("<----- Transpose of Matrix ----->")
    for i in range(row): 
        for j in range(col): 
            print(result[i][j], end = " ") 
        print() 

    if(matrix == result):
        print("Matrix is Symmetric")
    else:
        print("Matrix is not Symmetric")
    
def skew_symentric():
    row = int(input("Enter the number of rows : "))
    col = int(input("Enter the number of columns : "))
    print("Enter the elements of matrix: ")
    matrix = [[int(input()) for j in range(col)] for i in range(row)]
    print("<-------- Your Matrix -------->")
    for ele in matrix:
        print(ele)
    result = [[0 for i in range(row)] for j in range(col)]
    for r in range(row):
        for c in range(col):
            result[c][r] = -matrix[r][c]
            
            
    print("<----- Transpose of Matrix ----->")
    for i in range(row): 
        for j in range(col): 
            print(result[i][j], end = " ") 
        print() 

    if(matrix == result):
        print("Matrix is skew Symmetric")
       
    else:
        print("Matrix is not skew Symmetric")
        
        



            
def main():
    choice =True
    while(choice):
        print(""" <--------------------------------------------->
        1. Addition of matrix
        2. Subtraction of matrix
        3. Multiplication of matrix
        4. Transpose
        5. symentric
        6. Skew symentric 
        0. Exit
 <--------------------------------------------->""")
        choice = int(input("Enter your choice: "))
        if choice ==1:
            addition()
            
        elif choice ==2:
            subtraction()
            
        elif choice == 3:
            maltiplication()
            
        elif choice == 4:
             transpose()
                
        elif choice == 5:
             symentric()
        
        elif choice == 6:
              skew_symentic()
        
        
        elif choice ==0 :
            exit()
            
        else:
            print("Invalid choice!!")
    
    
if __name__ == "__main__":
    main()
# Out:
#  <--------------------------------------------->
#        1. Addition of matrix
#        2. Subtraction of matrix
#        3. Multiplication of matrix
#        4. Transpose
#        5. symentric
#        6. Skew symentric
#        0. Exit
# <--------------------------------------------->

# %%
def symentric():
    row = int(input("Enter the number of rows : "))
    col = int(input("Enter the number of columns : "))
    print("Enter the elements of matrix: ")
    matrix = [[int(input()) for j in range(col)] for i in range(row)]
    print("<-------- Your Matrix -------->")
    for ele in matrix:
        print(ele)
    result = [[0 for i in range(row)] for j in range(col)]
    for r in range(row):
        for c in range(col):
            result[c][r] = -matrix[r][c]
            
            
    print("<----- Transpose of Matrix ----->")
    for i in range(row): 
        for j in range(col): 
            print(result[i][j], end = " ") 
        print() 

    if(matrix == result):
        print("Matrix is skew Symmetric")
       
    else:
        print("Matrix is not skew Symmetric")
        
symentric()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-45b28e4e64f2> in <module>
#      25         print("Matrix is not skew Symmetric")
#      26
# ---> 27 symentric()
#
# <ipython-input-9-45b28e4e64f2> in symentric()
#       1 def symentric():
# ----> 2     row = int(input("Enter the number of rows : "))
#       3     col = int(input("Enter the number of columns : "))
#       4     print("Enter the elements of matrix: ")
#       5     matrix = [[int(input()) for j in range(col)] for i in range(row)]
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ...

# %%
import tweepy
from textblob import TextBlob 
from tweepy.auth import OAuthHandler
consume_key = 'ctmsobZp6F5A8ZvtVpl9m5KGe'
consumer_secret = 'gZ8UwGRrjhu496oI3QlcXqtNo1s9VeCjV5ca4bvxt55wODTLUC'
access_token = '1024698991399690240-wGlC8rkWbiCf9ydHkwte9Y15wkMCld'
access_token_secret = 'NmprUjrK2eQECAZomuaQVeHpY54fMcBYgVhdat9qMlyDY'

 #create OAuthHandler object
auth = OAuthHandler(consumer_key,consumer_secret)
    #set access token and secret
auth.set_access_token(access_token,access_token_secret)
    #create tweepy API object to fetch tweets
api = tweepy.API(auth)
public_tweets = api.search('Donald Trump')
for tweet in public_tweets:
    print(tweet.text)
    analysis=TextBlob(tweet.text)
    print(analysis.sentiment)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-00ad6b841bd9> in <module>
#       8
#       9  #create OAuthHandler object
# ---> 10 auth = OAuthHandler(consumer_key,consumer_secret)
#      11     #set access token and secret
#      12 auth.set_access_token(access_token,access_token_secret)
#
# NameError: name 'consumer_key' is not defined

# %%
d={}
d=setd

# %%
consume_key = 'mHGWIiS9C050jMCEZ6sgUQDnF'
consumer_secret = 'SvnP4Y6U5LZoK0bL7VRtBXWBKYjeBKzMpohhELjduZOR1YiHTA'
access_token = '1230932995219034112-nqIQofRA1W8EMu1CyFVMGZc5LToeqc'
access_token_secret = 'jhXmiQ81TRjoD3HrNH3zzIV44HRHVRGbjkj1qS2p8xSPS'
